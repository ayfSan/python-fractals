# %%
# !pip install ColabTurtle
# Out:
# Collecting ColabTurtle
#   Downloading ColabTurtle-2.1.0.tar.gz (6.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ColabTurtle
#   Building wheel for ColabTurtle (setup.py) ... done
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7643 sha256=fe34b4053a3da8e91e5a1dcda43ab0996561443e8e8c7d8975526716b2442c9c
#   Stored in directory: /root/.cache/pip/wheels/9f/af/64/ffd85f9858ed7d56b7293dcedbc9d461bf13c8cfc97e352bc8
# Successfully built ColabTurtle
# Installing collected packages: ColabTurtle
# Successfully installed ColabTurtle-2.1.0

# %%
from ColabTurtle.Turtle import *

# Тест: рисуем квадрат
initializeTurtle()  # Запускаем черепашку
speed(10)  # Скорость (1-13, 13 — самая быстрая)
penup()  # Поднимаем перо
goto(100, 100)  # Идём в стартовую точку
pendown()  # Опускаем перо
color('blue')  # Цвет линии

for _ in range(4):  # Цикл для 4 сторон
    forward(200)  # Вперёд 200 пикселей
    right(90)  # Поворот направо на 90 градусов
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="100" y1="100" x2="100.0" y2="-100.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="100.0" y1="-100.0" x2="300.0" y2="-100.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300.0" y1="-100.0" x2="300.0" y2="100.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300.0" y1="100.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,100.0,100.0) translate(82.0, 82.0)">
# <path style=" stroke:none;fill-rule:evenodd;fill:blue;fill-opacity:1;" d="M 18.214844 0.632812 C 16.109375 1.800781 15.011719 4.074219 15.074219 7.132812 L 15.085938 7.652344 L 14.785156 7.496094 C 13.476562 6.824219 11.957031 6.671875 10.40625 7.066406 C 8.46875 7.550781 6.515625 9.15625 4.394531 11.992188 C 3.0625 13.777344 2.679688 14.636719 3.042969 15.027344 L 3.15625 15.152344 L 3.519531 15.152344 C 4.238281 15.152344 4.828125 14.886719 8.1875 13.039062 C 9.386719 12.378906 10.371094 11.839844 10.378906 11.839844 C 10.386719 11.839844 10.355469 11.929688 10.304688 12.035156 C 9.832031 13.09375 9.257812 14.820312 8.96875 16.078125 C 7.914062 20.652344 8.617188 24.53125 11.070312 27.660156 C 11.351562 28.015625 11.363281 27.914062 10.972656 28.382812 C 8.925781 30.84375 7.945312 33.28125 8.238281 35.1875 C 8.289062 35.527344 8.28125 35.523438 8.917969 35.523438 C 10.941406 35.523438 13.074219 34.207031 15.136719 31.6875 C 15.359375 31.417969 15.328125 31.425781 15.5625 31.574219 C 16.292969 32.042969 18.023438 32.964844 18.175781 32.964844 C 18.335938 32.964844 19.941406 32.210938 20.828125 31.71875 C 20.996094 31.625 21.136719 31.554688 21.136719 31.558594 C 21.203125 31.664062 21.898438 32.414062 22.222656 32.730469 C 23.835938 34.300781 25.5625 35.132812 27.582031 35.300781 C 27.90625 35.328125 27.9375 35.308594 28.007812 34.984375 C 28.382812 33.242188 27.625 30.925781 25.863281 28.425781 L 25.542969 27.96875 L 25.699219 27.785156 C 28.945312 23.960938 29.132812 18.699219 26.257812 11.96875 L 26.207031 11.84375 L 27.945312 12.703125 C 31.53125 14.476562 32.316406 14.800781 33.03125 14.800781 C 33.976562 14.800781 33.78125 13.9375 32.472656 12.292969 C 28.519531 7.355469 25.394531 5.925781 21.921875 7.472656 L 21.558594 7.636719 L 21.578125 7.542969 C 21.699219 6.992188 21.761719 5.742188 21.699219 5.164062 C 21.496094 3.296875 20.664062 1.964844 19.003906 0.855469 C 18.480469 0.503906 18.457031 0.5 18.214844 0.632812"/>
# </g>
#       </svg>

# %%
from ColabTurtle.Turtle import *

# Вариация 1: Фрактальное дерево (рекурсия: ветки делятся на меньшие)
initializeTurtle()  # Новая черепашка для дерева
speed(13)
bgcolor('lightgreen')  # Фон для атмосферы
penup()
goto(500, 500)  # Старт снизу
pendown()
left(0)  # Смотрим вверх
color('brown')

def draw_tree(length, depth):
    if depth == 0:  # Если глубина 0 — стоп (листья)
        color('green')
        forward(5)  # Маленький лист
        backward(5)
        color('brown')
        return
    forward(length)  # Рисуем ветку
    left(30)  # Левая ветвь
    draw_tree(length * 0.7, depth - 1)  # Рекурсия: меньшая ветка
    right(60)  # Правая ветвь
    draw_tree(length * 0.7, depth - 1)  # Ещё рекурсия
    left(30)  # Возврат
    backward(length)  # Назад к стволу

draw_tree(100, 8)  # Запуск: длина 100, глубина 8 (поменяй для экспериментов)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill
stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="340.644" y1="347.32" x2="348.879" y2="347.32" stroke-linecap="round" style="stroke:brown;stroke-width:4"/><line x1="348.879" y1="347.32" x2="359.068" y2="341.438" stroke-linecap="round" style="stroke:brown;stroke-width:4"/><line x1="359.068" y1="341 ...

# %%
# Вариация 2: Снежинка Коха (геометрический фрактал: линии с "выпуклостями")
initializeTurtle()
speed(13)
penup()
goto(500, 500)  # Старт
pendown()
color('purple')

def koch_side(length, depth):
    if depth == 0:
        forward(length)  # Прямая линия
        return
    koch_side(length / 3, depth - 1)  # Рекурсия: треть линии
    left(60)
    koch_side(length / 3, depth - 1)
    right(120)
    koch_side(length / 3, depth - 1)
    left(60)
    koch_side(length / 3, depth - 1)

def koch_snowflake(length, depth):
    for _ in range(3):  # Три стороны снежинки
        koch_side(length, depth)
        right(120)  # Поворот для треугольника

koch_snowflake(300, 4)  # Запуск: длина 300, глубина 4 (больше — детальнее)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="500" y1="500" x2="500.0" y2="496.296" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="500.0" y1="496.296" x2="496.792" y2="494.444" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="496.792" y1="494.444" x2="500.0" y2="492.592" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="500.0" y1="492.592" x2="500.0" y2="488.888" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="500.0" y1="488.888" x2="496.792" y2="487.036" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="496.792" y1="487.036" x2="493.584" y2="488.888" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="493.584" y1="488.888" x2="493.584" y2="485.184" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="493.584" y1="485.184" x2="490.376" y2="483.332" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="490.376" y1="483.332" x2="493.584" y2="481.48" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="493.584" y1="481.48" x2="493.584" y2="477.776" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="493.584" y1="477.776" x2="496.792" y2="479.628" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="496.792" y1="479.628" x2="500.0" y2="477.776" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="500.0" y1="477.776" x2="500.0" y2="474.072" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="500.0" y1="474.072" x2="496.792" y2="472.22" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="496.792" y1="472.22" x2="500.0" y2="470.368" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="500.0" y1="470.368" x2="500.0" y2="466.664" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="500.0" y1="466.664" x2="496.792" y2="464.812" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="496.792" y1="464.812" x2="493.584" y2="466.664" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="493.584" y1="466.664" x2="493.584" y2="462.96" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="493.584" y1="462.96" x2="490.376" y2="461.108" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="490.376" y1="461.108" x2="487.168" y2="462.96" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="487.168" y1="462.96" x2="487.168" y2="466.664" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="487.168" y1="466.664" x2="483.96" y2="464.812" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="483.96" y1="464.812" x2="480.752" y2="466.664" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="480.752" y1="466.664" x2="480.752" y2="462.96" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="480.752" y1="462.96" x2="477.544" y2="461.108" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="477.544" y1="461.108" x2="480.752" y2="459.256" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="480.752" y1="459.256" x2="480.752" y2="455.552" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="480.752" y1="455.552" x2="477.544" y2="453.7" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="477.544" y1="453.7" x2="474.336" y2="455.552" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="474.336" y1="455.552" x2="474.336" y2="451.848" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="474.336" y1="451.848" x2="471.128" y2="449.996" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="471.128" y1="449.996" x2="474.336" y2="448.144" stroke-linecap="round" style="stroke:purple;stroke-width:4"/><line x1="474.336" y1="448.144" x2="474.336" y2="444.44" stroke-linecap="round" style="stroke:purple;stroke-width:4"/ ...
